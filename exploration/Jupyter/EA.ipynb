# %%
import numpy as np
import scipy
import matplotlib.pyplot as plt
import os

# %%
data_path = "/SCRATCH/TIC270/dvalesp/DigiVolCan/data/involcan/features/"
os.path.exists(data_path)
data = scipy.io.loadmat(data_path+"270.mat")

# %%
X = data["FFT_128_BIN"]
X = np.squeeze(X)

# %%
np.max(X), np.min(X)
# Out:
# (np.float64(57982058495.99999), np.float64(0.0))
